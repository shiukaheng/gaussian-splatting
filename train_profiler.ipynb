# %%
from train import *

def train_profiler(iterations=2000, train_cam_limit=263):
    parser = ArgumentParser(description="Training script parameters")
    lp = ModelParams(parser)
    op = OptimizationParams(parser)
    pp = PipelineParams(parser)
    parser.add_argument('--ip', type=str, default="127.0.0.1")
    parser.add_argument('--port', type=int, default=6009)
    parser.add_argument('--debug_from', type=int, default=-1)
    parser.add_argument('--detect_anomaly', action='store_true', default=False)
    parser.add_argument("--test_iterations", nargs="+", type=int, default=[7_000, 30_000])
    parser.add_argument("--save_iterations", nargs="+", type=int, default=[7_000, 30_000])
    parser.add_argument("--quiet", action="store_true")
    parser.add_argument("--checkpoint_iterations", nargs="+", type=int, default=[])
    parser.add_argument("--start_checkpoint", type=str, default = None)
    sysargs = ['-s', '.\\test_datasets\\db\\drjohnson\\', '--iterations', str(iterations)]
    args = parser.parse_args(sysargs)

    args.save_iterations.append(args.iterations)

    print("Optimizing " + args.model_path)

    # Initialize system state (RNG)
    safe_state(args.quiet)

    # Start GUI server, configure and run training
    torch.autograd.set_detect_anomaly(args.detect_anomaly)
    stats, num_cameras = training(lp.extract(args), op.extract(args), pp.extract(args), args.test_iterations, args.save_iterations, args.checkpoint_iterations, args.start_checkpoint, args.debug_from, train_cam_limit=train_cam_limit)

    # All done
    print("\nTraining complete.")

    # For each dict in stats, add "num_cameras" key with value num_cameras
    for stat in stats:
        stat["num_cameras"] = num_cameras
    
    return stats

# %%
import numpy as np

camera_limits = np.linspace(0, 263, 10+1, dtype=int)
camera_limits = camera_limits[1:]

stats = []
for camera_limit in camera_limits:
    stats.append(train_profiler(iterations=2000, train_cam_limit=camera_limit))

# flatten stats - list of lists into list
flattened_stats = [item for sublist in stats for item in sublist]
# Out:
# Training progress: 100%|██████████| 2000/2000 [00:49<00:00, 40.36it/s, Loss=0.0382859]
# Training progress: 100%|██████████| 2000/2000 [00:49<00:00, 40.40it/s, Loss=0.0473685]
# Training progress: 100%|██████████| 2000/2000 [00:50<00:00, 39.88it/s, Loss=0.0464170]
# Training progress: 100%|██████████| 2000/2000 [00:51<00:00, 39.20it/s, Loss=0.0535924]
# Training progress: 100%|██████████| 2000/2000 [00:47<00:00, 41.69it/s, Loss=0.0560187]
# Training progress: 100%|██████████| 2000/2000 [00:50<00:00, 39.40it/s, Loss=0.0837425]
# Training progress: 100%|██████████| 2000/2000 [00:52<00:00, 37.92it/s, Loss=0.0572357]
# Training progress: 100%|██████████| 2000/2000 [00:50<00:00, 39.80it/s, Loss=0.0686252]
# Training progress: 100%|██████████| 2000/2000 [00:51<00:00, 38.91it/s, Loss=0.0472431]
# Training progress: 100%|██████████| 2000/2000 [00:49<00:00, 40.18it/s, Loss=0.0608590]
# Training progress: 100%|██████████| 2000/2000 [00:50<00:00, 39.29it/s, Loss=0.0715118]

# %%
flattened_stats
# Out:
# [{'iter': 600,
#   'num_points': 94880,
#   'memory': 446.43017578125,
#   'num_cameras': 23},
#  {'iter': 700,
#   'num_points': 124402,
#   'memory': 473.18017578125,
#   'num_cameras': 23},
#  {'iter': 800,
#   'num_points': 160716,
#   'memory': 514.80908203125,
#   'num_cameras': 23},
#  {'iter': 900,
#   'num_points': 201539,
#   'memory': 562.36767578125,
#   'num_cameras': 23},
#  {'iter': 1000,
#   'num_points': 244436,
#   'memory': 611.4228515625,
#   'num_cameras': 23},
#  {'iter': 1100,
#   'num_points': 293086,
#   'memory': 666.30712890625,
#   'num_cameras': 23},
#  {'iter': 1200,
#   'num_points': 344543,
#   'memory': 728.3837890625,
#   'num_cameras': 23},
#  {'iter': 1300,
#   'num_points': 397827,
#   'memory': 789.88623046875,
#   'num_cameras': 23},
#  {'iter': 1400,
#   'num_points': 453441,
#   'memory': 853.3876953125,
#   'num_cameras': 23},
#  {'iter': 1500,
#   'num_points': 510694,
#   'memory': 920.16259765625,
#   'num_cameras': 23},
#  {'iter': 1600, 'num_points': 570461, 'memory': 994.015625, 'num_cameras': 23},
#  {'iter': 1700,
#   'num_points': 632789,
#   'memory': 1065.470703125,
#   'num_cameras': 23},
#  {'iter': 1800,
#   'num_points': 695173,
#   'memory': 1137.7861328125,
#   'num_cameras': 23},
#  {'iter': 1900,
#   'num_points': 757160,
#   'memory': 1212.0712890625,
#   'num_cameras': 23},
#  {'iter': 2000,
#   'num_points': 822674,
#   'memory': 1287.11865234375,
#   'num_cameras': 23},
#  {'iter': 600,
#   'num_points': 88220,
#   'memory': 777.0380859375,
#   'num_cameras': 47},
#  {'iter': 700,
#   'num_points': 108322,
#   'memory': 793.64794921875,
#   'num_cameras': 47},
#  {'iter': 800,
#   'num_points': 132245,
#   'memory': 822.93017578125,
#   'num_cameras': 47},
#  {'iter': 900, 'num_points': 157738, 'memory': 851.9921875, 'num_cameras': 47},
#  {'iter': 1000,
#   'num_points': 185826,
#   'memory': 884.81689453125,
#   'num_cameras': 47},
#  {'iter': 1100,
#   'num_points': 217495,
#   'memory': 922.81982421875,
#   'num_cameras': 47},
#  {'iter': 1200,
#   'num_points': 248807,
#   'memory': 959.33935546875,
#   'num_cameras': 47},
#  {'iter': 1300,
#   'num_points': 280854,
#   'memory': 997.126953125,
#   'num_cameras': 47},
#  {'iter': 1400,
#   'num_points': 315413,
#   'memory': 1038.08154296875,
#   'num_cameras': 47},
#  {'iter': 1500,
#   'num_points': 347714,
#   'memory': 1079.51220703125,
#   'num_cameras': 47},
#  {'iter': 1600,
#   'num_points': 381860,
#   'memory': 1116.8818359375,
#   'num_cameras': 47},
#  {'iter': 1700,
#   'num_points': 418056,
#   'memory': 1155.79638671875,
#   'num_cameras': 47},
#  {'iter': 1800,
#   'num_points': 455184,
#   'memory': 1198.07763671875,
#   'num_cameras': 47},
#  {'iter': 1900,
#   'num_points': 491519,
#   'memory': 1245.47509765625,
#   'num_cameras': 47},
#  {'iter': 2000,
#   'num_points': 528738,
#   'memory': 1289.2939453125,
#   'num_cameras': 47},
#  {'iter': 600,
#   'num_points': 87347,
#   'memory': 1107.28466796875,
#   'num_cameras': 71},
#  {'iter': 700,
#   'num_points': 106123,
#   'memory': 1123.63720703125,
#   'num_cameras': 71},
#  {'iter': 800,
#   'num_points': 127456,
#   'memory': 1147.5556640625,
#   'num_cameras': 71},
#  {'iter': 900,
#   'num_points': 151461,
#   'memory': 1176.947265625,
#   'num_cameras': 71},
#  {'iter': 1000,
#   'num_points': 175339,
#   'memory': 1204.623046875,
#   'num_cameras': 71},
#  {'iter': 1100,
#   'num_points': 202597,
#   'memory': 1236.451171875,
#   'num_cameras': 71},
#  {'iter': 1200,
#   'num_points': 232049,
#   'memory': 1270.6923828125,
#   'num_cameras': 71},
#  {'iter': 1300,
#   'num_points': 260365,
#   'memory': 1303.08203125,
#   'num_cameras': 71},
#  {'iter': 1400,
#   'num_points': 289798,
#   'memory': 1339.45068359375,
#   'num_cameras': 71},
#  {'iter': 1500,
#   'num_points': 323828,
#   'memory': 1377.2314453125,
#   'num_cameras': 71},
#  {'iter': 1600,
#   'num_points': 356529,
#   'memory': 1420.06591796875,
#   'num_cameras': 71},
#  {'iter': 1700,
#   'num_points': 387568,
#   'memory': 1454.13330078125,
#   'num_cameras': 71},
#  {'iter': 1800,
#   'num_points': 417897,
#   'memory': 1489.5439453125,
#   'num_cameras': 71},
#  {'iter': 1900,
#   'num_points': 452792,
#   'memory': 1532.04638671875,
#   'num_cameras': 71},
#  {'iter': 2000,
#   'num_points': 485956,
#   'memory': 1574.26708984375,
#   'num_cameras': 71},
#  {'iter': 600,
#   'num_points': 86736,
#   'memory': 1436.49267578125,
#   'num_cameras': 95},
#  {'iter': 700,
#   'num_points': 103243,
#   'memory': 1451.947265625,
#   'num_cameras': 95},
#  {'iter': 800,
#   'num_points': 123107,
#   'memory': 1475.5322265625,
#   'num_cameras': 95},
#  {'iter': 900,
#   'num_points': 147048,
#   'memory': 1501.57763671875,
#   'num_cameras': 95},
#  {'iter': 1000,
#   'num_points': 172260,
#   'memory': 1531.19482421875,
#   'num_cameras': 95},
#  {'iter': 1100,
#   'num_points': 198676,
#   'memory': 1564.36669921875,
#   'num_cameras': 95},
#  {'iter': 1200,
#   'num_points': 223998,
#   'memory': 1591.78662109375,
#   'num_cameras': 95},
#  {'iter': 1300,
#   'num_points': 256785,
#   'memory': 1627.458984375,
#   'num_cameras': 95},
#  {'iter': 1400,
#   'num_points': 283796,
#   'memory': 1668.5458984375,
#   'num_cameras': 95},
#  {'iter': 1500,
#   'num_points': 316581,
#   'memory': 1702.06103515625,
#   'num_cameras': 95},
#  {'iter': 1600,
#   'num_points': 348654,
#   'memory': 1742.56884765625,
#   'num_cameras': 95},
#  {'iter': 1700,
#   'num_points': 381042,
#   'memory': 1779.09619140625,
#   'num_cameras': 95},
#  {'iter': 1800,
#   'num_points': 413168,
#   'memory': 1817.24609375,
#   'num_cameras': 95},
#  {'iter': 1900,
#   'num_points': 446316,
#   'memory': 1854.96728515625,
#   'num_cameras': 95},
#  {'iter': 2000,
#   'num_points': 479706,
#   'memory': 1893.19970703125,
#   'num_cameras': 95},
#  {'iter': 600,
#   'num_points': 86662,
#   'memory': 1765.58935546875,
#   'num_cameras': 119},
#  {'iter': 700,
#   'num_points': 102160,
#   'memory': 1779.94384765625,
#   'num_cameras': 119},
#  {'iter': 800,
#   'num_points': 124193,
#   'memory': 1805.1640625,
#   'num_cameras': 119},
#  {'iter': 900,
#   'num_points': 146477,
#   'memory': 1831.8544921875,
#   'num_cameras': 119},
#  {'iter': 1000,
#   'num_points': 172174,
#   'memory': 1860.7236328125,
#   'num_cameras': 119},
#  {'iter': 1100,
#   'num_points': 198238,
#   'memory': 1893.32861328125,
#   'num_cameras': 119},
#  {'iter': 1200,
#   'num_points': 225214,
#   'memory': 1925.30517578125,
#   'num_cameras': 119},
#  {'iter': 1300,
#   'num_points': 252538,
#   'memory': 1957.9775390625,
#   'num_cameras': 119},
#  {'iter': 1400,
#   'num_points': 284287,
#   'memory': 1994.9833984375,
#   'num_cameras': 119},
#  {'iter': 1500,
#   'num_points': 311626,
#   'memory': 2029.23876953125,
#   'num_cameras': 119},
#  {'iter': 1600,
#   'num_points': 346467,
#   'memory': 2070.8642578125,
#   'num_cameras': 119},
#  {'iter': 1700,
#   'num_points': 377605,
#   'memory': 2106.64306640625,
#   'num_cameras': 119},
#  {'iter': 1800,
#   'num_points': 412864,
#   'memory': 2145.08740234375,
#   'num_cameras': 119},
#  {'iter': 1900,
#   'num_points': 444993,
#   'memory': 2183.05224609375,
#   'num_cameras': 119},
#  {'iter': 2000,
#   'num_points': 478169,
#   'memory': 2221.09423828125,
#   'num_cameras': 119},
#  {'iter': 600,
#   'num_points': 86496,
#   'memory': 2094.69677734375,
#   'num_cameras': 143},
#  {'iter': 700,
#   'num_points': 102372,
#   'memory': 2107.77783203125,
#   'num_cameras': 143},
#  {'iter': 800,
#   'num_points': 126547,
#   'memory': 2133.7255859375,
#   'num_cameras': 143},
#  {'iter': 900,
#   'num_points': 145891,
#   'memory': 2161.22705078125,
#   'num_cameras': 143},
#  {'iter': 1000,
#   'num_points': 170535,
#   'memory': 2186.994140625,
#   'num_cameras': 143},
#  {'iter': 1100,
#   'num_points': 196983,
#   'memory': 2219.681640625,
#   'num_cameras': 143},
#  {'iter': 1200,
#   'num_points': 222417,
#   'memory': 2250.1865234375,
#   'num_cameras': 143},
#  {'iter': 1300,
#   'num_points': 254129,
#   'memory': 2283.14990234375,
#   'num_cameras': 143},
#  {'iter': 1400,
#   'num_points': 281193,
#   'memory': 2321.2890625,
#   'num_cameras': 143},
#  {'iter': 1500,
#   'num_points': 310703,
#   'memory': 2357.49853515625,
#   'num_cameras': 143},
#  {'iter': 1600,
#   'num_points': 347040,
#   'memory': 2393.04443359375,
#   'num_cameras': 143},
#  {'iter': 1700,
#   'num_points': 380377,
#   'memory': 2439.02294921875,
#   'num_cameras': 143},
#  {'iter': 1800,
#   'num_points': 408485,
#   'memory': 2473.73876953125,
#   'num_cameras': 143},
#  {'iter': 1900,
#   'num_points': 441241,
#   'memory': 2507.35107421875,
#   'num_cameras': 143},
#  {'iter': 2000,
#   'num_points': 479597,
#   'memory': 2547.5146484375,
#   'num_cameras': 143},
#  {'iter': 600,
#   'num_points': 86237,
#   'memory': 2421.521484375,
#   'num_cameras': 167},
#  {'iter': 700,
#   'num_points': 101760,
#   'memory': 2435.962890625,
#   'num_cameras': 167},
#  {'iter': 800,
#   'num_points': 123647,
#   'memory': 2461.85888671875,
#   'num_cameras': 167},
#  {'iter': 900,
#   'num_points': 147156,
#   'memory': 2488.10546875,
#   'num_cameras': 167},
#  {'iter': 1000,
#   'num_points': 171000,
#   'memory': 2516.31494140625,
#   'num_cameras': 167},
#  {'iter': 1100,
#   'num_points': 199092,
#   'memory': 2547.14013671875,
#   'num_cameras': 167},
#  {'iter': 1200,
#   'num_points': 223998,
#   'memory': 2581.259765625,
#   'num_cameras': 167},
#  {'iter': 1300,
#   'num_points': 250684,
#   'memory': 2612.42724609375,
#   'num_cameras': 167},
#  {'iter': 1400, 'num_points': 282238, 'memory': 2650.125, 'num_cameras': 167},
#  {'iter': 1500,
#   'num_points': 312151,
#   'memory': 2686.84033203125,
#   'num_cameras': 167},
#  {'iter': 1600,
#   'num_points': 343010,
#   'memory': 2722.2685546875,
#   'num_cameras': 167},
#  {'iter': 1700,
#   'num_points': 373379,
#   'memory': 2758.435546875,
#   'num_cameras': 167},
#  {'iter': 1800,
#   'num_points': 403954,
#   'memory': 2792.91845703125,
#   'num_cameras': 167},
#  {'iter': 1900,
#   'num_points': 441158,
#   'memory': 2833.80712890625,
#   'num_cameras': 167},
#  {'iter': 2000,
#   'num_points': 475092,
#   'memory': 2874.17724609375,
#   'num_cameras': 167},
#  {'iter': 600,
#   'num_points': 86740,
#   'memory': 2750.37744140625,
#   'num_cameras': 191},
#  {'iter': 700,
#   'num_points': 102484,
#   'memory': 2765.47705078125,
#   'num_cameras': 191},
#  {'iter': 800,
#   'num_points': 120191,
#   'memory': 2789.71728515625,
#   'num_cameras': 191},
#  {'iter': 900,
#   'num_points': 144987,
#   'memory': 2814.205078125,
#   'num_cameras': 191},
#  {'iter': 1000,
#   'num_points': 175223,
#   'memory': 2845.775390625,
#   'num_cameras': 191},
#  {'iter': 1100,
#   'num_points': 201493,
#   'memory': 2876.79443359375,
#   'num_cameras': 191},
#  {'iter': 1200,
#   'num_points': 229968,
#   'memory': 2911.66845703125,
#   'num_cameras': 191},
#  {'iter': 1300,
#   'num_points': 256035,
#   'memory': 2944.462890625,
#   'num_cameras': 191},
#  {'iter': 1400,
#   'num_points': 288526,
#   'memory': 2983.51025390625,
#   'num_cameras': 191},
#  {'iter': 1500,
#   'num_points': 319040,
#   'memory': 3018.4013671875,
#   'num_cameras': 191},
#  {'iter': 1600,
#   'num_points': 347422,
#   'memory': 3055.37060546875,
#   'num_cameras': 191},
#  {'iter': 1700,
#   'num_points': 386619,
#   'memory': 3095.689453125,
#   'num_cameras': 191},
#  {'iter': 1800,
#   'num_points': 418865,
#   'memory': 3138.4033203125,
#   'num_cameras': 191},
#  {'iter': 1900,
#   'num_points': 456051,
#   'memory': 3174.82275390625,
#   'num_cameras': 191},
#  {'iter': 2000,
#   'num_points': 485535,
#   'memory': 3215.65625,
#   'num_cameras': 191},
#  {'iter': 600,
#   'num_points': 86314,
#   'memory': 3077.46240234375,
#   'num_cameras': 215},
#  {'iter': 700,
#   'num_points': 101065,
#   'memory': 3092.263671875,
#   'num_cameras': 215},
#  {'iter': 800,
#   'num_points': 120626,
#   'memory': 3113.5546875,
#   'num_cameras': 215},
#  {'iter': 900,
#   'num_points': 141978,
#   'memory': 3138.7119140625,
#   'num_cameras': 215},
#  {'iter': 1000,
#   'num_points': 165917,
#   'memory': 3163.0361328125,
#   'num_cameras': 215},
#  {'iter': 1100,
#   'num_points': 195174,
#   'memory': 3196.2412109375,
#   'num_cameras': 215},
#  {'iter': 1200,
#   'num_points': 222200,
#   'memory': 3230.00341796875,
#   'num_cameras': 215},
#  {'iter': 1300,
#   'num_points': 248436,
#   'memory': 3261.78515625,
#   'num_cameras': 215},
#  {'iter': 1400,
#   'num_points': 278556,
#   'memory': 3300.56396484375,
#   'num_cameras': 215},
#  {'iter': 1500,
#   'num_points': 308610,
#   'memory': 3337.46044921875,
#   'num_cameras': 215},
#  {'iter': 1600,
#   'num_points': 337385,
#   'memory': 3368.8828125,
#   'num_cameras': 215},
#  {'iter': 1700,
#   'num_points': 371438,
#   'memory': 3407.83642578125,
#   'num_cameras': 215},
#  {'iter': 1800,
#   'num_points': 404146,
#   'memory': 3447.48681640625,
#   'num_cameras': 215},
#  {'iter': 1900,
#   'num_points': 436534,
#   'memory': 3486.54833984375,
#   'num_cameras': 215},
#  {'iter': 2000,
#   'num_points': 469697,
#   'memory': 3522.00439453125,
#   'num_cameras': 215},
#  {'iter': 600,
#   'num_points': 86348,
#   'memory': 3404.38623046875,
#   'num_cameras': 239},
#  {'iter': 700,
#   'num_points': 103686,
#   'memory': 3421.751953125,
#   'num_cameras': 239},
#  {'iter': 800,
#   'num_points': 123217,
#   'memory': 3445.03662109375,
#   'num_cameras': 239},
#  {'iter': 900, 'num_points': 147405, 'memory': 3469.78125, 'num_cameras': 239},
#  {'iter': 1000,
#   'num_points': 171081,
#   'memory': 3499.35595703125,
#   'num_cameras': 239},
#  {'iter': 1100,
#   'num_points': 196704,
#   'memory': 3526.8291015625,
#   'num_cameras': 239},
#  {'iter': 1200,
#   'num_points': 222836,
#   'memory': 3558.255859375,
#   'num_cameras': 239},
#  {'iter': 1300,
#   'num_points': 250153,
#   'memory': 3589.9169921875,
#   'num_cameras': 239},
#  {'iter': 1400,
#   'num_points': 283318,
#   'memory': 3627.4169921875,
#   'num_cameras': 239},
#  {'iter': 1500,
#   'num_points': 311232,
#   'memory': 3667.767578125,
#   'num_cameras': 239},
#  {'iter': 1600,
#   'num_points': 339950,
#   'memory': 3701.35595703125,
#   'num_cameras': 239},
#  {'iter': 1700,
#   'num_points': 376398,
#   'memory': 3739.95849609375,
#   'num_cameras': 239},
#  {'iter': 1800,
#   'num_points': 406208,
#   'memory': 3777.7841796875,
#   'num_cameras': 239},
#  {'iter': 1900,
#   'num_points': 440419,
#   'memory': 3813.548828125,
#   'num_cameras': 239},
#  {'iter': 2000,
#   'num_points': 472504,
#   'memory': 3853.96240234375,
#   'num_cameras': 239},
#  {'iter': 600,
#   'num_points': 86599,
#   'memory': 3730.81005859375,
#   'num_cameras': 263},
#  {'iter': 700,
#   'num_points': 103500,
#   'memory': 3747.767578125,
#   'num_cameras': 263},
#  {'iter': 800,
#   'num_points': 123135,
#   'memory': 3770.91748046875,
#   'num_cameras': 263},
#  {'iter': 900,
#   'num_points': 143864,
#   'memory': 3794.44287109375,
#   'num_cameras': 263},
#  {'iter': 1000,
#   'num_points': 168853,
#   'memory': 3820.939453125,
#   'num_cameras': 263},
#  {'iter': 1100,
#   'num_points': 199541,
#   'memory': 3855.15087890625,
#   'num_cameras': 263},
#  {'iter': 1200,
#   'num_points': 229535,
#   'memory': 3890.4931640625,
#   'num_cameras': 263},
#  {'iter': 1300,
#   'num_points': 259264,
#   'memory': 3925.96142578125,
#   'num_cameras': 263},
#  {'iter': 1400,
#   'num_points': 285764,
#   'memory': 3964.06298828125,
#   'num_cameras': 263},
#  {'iter': 1500,
#   'num_points': 322794,
#   'memory': 4003.72314453125,
#   'num_cameras': 263},
#  {'iter': 1600,
#   'num_points': 353469,
#   'memory': 4043.2158203125,
#   'num_cameras': 263},
#  {'iter': 1700,
#   'num_points': 381804,
#   'memory': 4074.96337890625,
#   'num_cameras': 263},
#  {'iter': 1800,
#   'num_points': 415205,
#   'memory': 4110.75244140625,
#   'num_cameras': 263},
#  {'iter': 1900,
#   'num_points': 451203,
#   'memory': 4150.56201171875,
#   'num_cameras': 263},
#  {'iter': 2000,
#   'num_points': 483983,
#   'memory': 4192.59912109375,
#   'num_cameras': 263}]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1644\1025822078.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\seaborn\rcmod.py in <module>
#       3 import matplotlib as mpl
#       4 from cycler import cycler
# ----> 5 from . import palettes
#       6
#       7
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\seaborn\palettes.py in <module>
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11 from ._compat import get_colormap
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\seaborn\utils.py in <module>
#       9
#      10 import numpy as np
# ---> 11 import pandas as pd
#      12 import matplotlib as mpl
#      13 from matplotlib.colors import to_rgb
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\pandas\__init__.py in <module>
#     142 from pandas.util._print_versions import show_versions
#     143
# --> 144 from pandas.io.api import (
#     145     # excel
#     146     ExcelFile,
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\pandas\io\api.py in <module>
#       6
#       7 from pandas.io.clipboards import read_clipboard
# ----> 8 from pandas.io.excel import ExcelFile, ExcelWriter, read_excel
#       9 from pandas.io.feather_format import read_feather
#      10 from pandas.io.gbq import read_gbq
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\pandas\io\excel\__init__.py in <module>
# ----> 1 from pandas.io.excel._base import ExcelFile, ExcelWriter, read_excel
#       2 from pandas.io.excel._odswriter import ODSWriter as _ODSWriter
#       3 from pandas.io.excel._openpyxl import OpenpyxlWriter as _OpenpyxlWriter
#       4 from pandas.io.excel._util import register_writer
#       5 from pandas.io.excel._xlsxwriter import XlsxWriter as _XlsxWriter
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\pandas\io\excel\_base.py in <module>
#      31     pop_header_name,
#      32 )
# ---> 33 from pandas.io.parsers import TextParser
#      34
#      35 _read_excel_doc = (
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\pandas\io\parsers\__init__.py in <module>
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#
# c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\pandas\io\parsers\readers.py in <module>
#      15 import pandas._libs.lib as lib
#      16 from pandas._libs.parsers import STR_NA_VALUES
# ---> 17 from pandas._typing import (
#      18     ArrayLike,
#      19     DtypeArg,
#
# ImportError: cannot import name 'DtypeArg' from 'pandas._typing' (c:\Users\heng\miniconda3\envs\gaussian_splatting\lib\site-packages\pandas\_typing.py)

# %%
stats[1]
# Out:
# [{'iter': 600,
#   'num_points': 88220,
#   'memory': 777.0380859375,
#   'num_cameras': 47},
#  {'iter': 700,
#   'num_points': 108322,
#   'memory': 793.64794921875,
#   'num_cameras': 47},
#  {'iter': 800,
#   'num_points': 132245,
#   'memory': 822.93017578125,
#   'num_cameras': 47},
#  {'iter': 900, 'num_points': 157738, 'memory': 851.9921875, 'num_cameras': 47},
#  {'iter': 1000,
#   'num_points': 185826,
#   'memory': 884.81689453125,
#   'num_cameras': 47},
#  {'iter': 1100,
#   'num_points': 217495,
#   'memory': 922.81982421875,
#   'num_cameras': 47},
#  {'iter': 1200,
#   'num_points': 248807,
#   'memory': 959.33935546875,
#   'num_cameras': 47},
#  {'iter': 1300,
#   'num_points': 280854,
#   'memory': 997.126953125,
#   'num_cameras': 47},
#  {'iter': 1400,
#   'num_points': 315413,
#   'memory': 1038.08154296875,
#   'num_cameras': 47},
#  {'iter': 1500,
#   'num_points': 347714,
#   'memory': 1079.51220703125,
#   'num_cameras': 47},
#  {'iter': 1600,
#   'num_points': 381860,
#   'memory': 1116.8818359375,
#   'num_cameras': 47},
#  {'iter': 1700,
#   'num_points': 418056,
#   'memory': 1155.79638671875,
#   'num_cameras': 47},
#  {'iter': 1800,
#   'num_points': 455184,
#   'memory': 1198.07763671875,
#   'num_cameras': 47},
#  {'iter': 1900,
#   'num_points': 491519,
#   'memory': 1245.47509765625,
#   'num_cameras': 47},
#  {'iter': 2000,
#   'num_points': 528738,
#   'memory': 1289.2939453125,
#   'num_cameras': 47}]

# %%
# Plot memory wrt iterations (stats is list of dicts)
def plot_memory(stats):
    # Get memory usage
    memory = []
    for stat in stats:
        memory.append(stat["memory"])

    # Plot memory usage
    plt.plot(memory)
    plt.xlabel("Iteration")
    plt.ylabel("Memory (MB)")
    plt.title("Memory usage over iterations")
    plt.show()

# %%
plot_memory(stats)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1644\4085803393.py in <module>
# ----> 1 plot_memory(stats)
#
# ~\AppData\Local\Temp\ipykernel_1644\3097377511.py in plot_memory(stats)
#       4     memory = []
#       5     for stat in stats:
# ----> 6         memory.append(stat["memory"])
#       7
#       8     # Plot memory usage
#
# TypeError: list indices must be integers or slices, not str

# %%
# Plot memory wrt number of cameras
def
# Out:
#   File "C:\Users\heng\AppData\Local\Temp\ipykernel_1644\601827372.py", line 2
#     def
#        ^
# SyntaxError: invalid syntax

# %%
# Plot memory wrt number of splats
